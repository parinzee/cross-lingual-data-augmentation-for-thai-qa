# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import table

# %%
data = pd.read_parquet("data/06_calculate_distance.parquet")
data
# Out:
#                                                      id  \
# 0     9ce376f4446e5b43e55d6f545c1adec7975a51d9085156...
# 1     54421ea8bf2c7778b1d27a9e878c31aee3361455e767f0...
# 2     287fa29b965a1ba84011bb12ffafb5194984a955d851eb...
# 3     35adee7e78d0ae214238db68c9b524e01b1997ee7bf1ad...
# 4     e4952f44ce25aa622976eb9d382ae03cfa38d3d081f0df...
# ...                                                 ...
# 7838  5f74195cacdd4383213ee1ad9cc2e41497f0b92a499572...
# 7839  dc8efd91dc077986111111359e2b3384ef160c94014335...
# 7840  bfb838532a67f8b1f043d1e35bfe49572efb323a932ea9...
# 7841  94e4944a0238f373dafd9d9c41c2a3ab57a461ebbcd315...
# 7842  12f2d41cbb36268af575971ed19bdf05fb38c2b0c00559...
#
#                                                 context  \
# 0     พัทธ์ธีรา ศรุติพงศ์โภคิน (เกิด 3 ธันวาคม พ.ศ. ...
# 1     คลีโอพัตราที่ 7 ฟิโลพาเธอร์ (กรีก: Κλεοπάτρα θ...
# 2     ออสเตรเลีย (อังกฤษ: Australia) หรือชื่อทางการค...
# 3     วันสันติภาพไทย คือ วันที่ 16 สิงหาคม ของทุกปี ...
# 4     นิวซีแลนด์ (อังกฤษ: New Zealand มาวรี: Aotearo...
# ...                                                 ...
# 7838  สีดำ หมายถึง สีแห่งศอของพระศิวะที่ดื่มยาพิษเพื...
# 7839  ยัน ฟัน ไอก์ (Dutch: Jan van Eyck ราวก่อน ค.ศ....
# 7840  ไบโอช็อก อินฟินิต (English: BioShock Infinite)...
# 7841  ยู ซึง-โฮเดบิวต์เมื่อปี 1999 กับผลงานโฆษณาของ ...
# 7842  รองศาสตราจารย์ หม่อมราชวงศ์สุขุมพันธุ์ บริพัตร...
#
#                                                  th_aug  \
# 0     Phatthira Saruritphong Phokin (เกิด 3 ธันวาคม ...
# 1     คลีโอพัตรา 7 ฟิโลพาเธอร์ (กรีก: κλεοπάτραθεάφι...
# 2     ออสเตรเลียหรือชื่อทางการคือกลุ่มออสเตรเลีย (เค...
# 3     วันสันติภาพไทยเป็นวันที่ 16 สิงหาคมทุกปีซึ่งเป...
# 4     นิวซีแลนด์ (ภาษาอังกฤษ: นิวซีแลนด์: Aotearoa ห...
# ...                                                 ...
# 7838  สีดำหมายถึงสีของพระอิศวรที่ดื่มเพื่อปกป้องมนุษ...
# 7839  ดัตช์: Jan Van Eyck, ประมาณ 1395 - ก่อนวันที่ ...
# 7840  BioShock Infinite เป็นวิดีโอของบุคคลแรกที่ถ่าย...
# 7841  Yoo Seung-ho เปิดตัวในปี 1999 ด้วยการโฆษณาของ ...
# 7842  รองศาสตราจารย์ Mom City Sukhumphan Boriphat (2...
#
#                                         th_fasttext_aug  \
# 0     พัทธ์ธีดาเล ศรุติพงศ์โภคิน (เกิด 3 21มกราคม พ....
# 1     คลีโอพัตราที่ 58 Zafina ทริงเงิพาเธอร์ (กรีก :...
# 2     ออสเตรเลีย6 (อังกฤษ : Australia ) บางทีชื่อทาง...
# 3     เมื่ออนุสนธิการ์ตูน2ภาษา เรียก วันที่ YIMSOO ส...
# 4     นิวซีแลนด์ (อังกฤษ : New Zealand มาวอัลแฟ : Ao...
# ...                                                 ...
# 7838  สีดำ หมายถึง สีแห่งศอของพระศิวะที่ดื่มยาพิษเพื...
# 7839  ยัน ฟัน ไอก์ (Dutch: Jan van Eyck ราวก่อน ค.ศ....
# 7840  ไบโอช็อก อินฟินิต (English: BioShock Infinite)...
# 7841  ยู ซึง-โฮเดบิวต์เมื่อปี 1999 กับผลงานโฆษณาของ ...
# 7842  รองศาสตราจารย์ หม่อมราชวงศ์สุขุมพันธุ์ บริพัตร...
#
#                                          th_llm_gec_aug  \
# 0     Phatthira Saruritphong Phokin (เกิด 3 ธันวาคม ...
# 1     Cleopatra VII Philopator (กรีก: κλεοπάτραθεάφι...
# 2     ออสเตรเลียซึ่งเป็นที่รู้จักอย่างเป็นทางการในฐา...
# 3     วันแห่งความสงบสุขของไทยมีการเฉลิมฉลองวันที่ 16...
# 4     นิวซีแลนด์ (ภาษาอังกฤษ: นิวซีแลนด์ เมารี: Aote...
# ...                                                 ...
# 7838  สีดำเป็นสัญลักษณ์ของอะไรในบริบทของเรื่องราวของ...
# 7839  Jan Van Eyck (ประมาณ 1395- ก่อนวันที่ 9 กรกฎาค...
# 7840  BioShock Infinite เป็นวิดีโอเกมยิงปืนคนแรกโดยเ...
# 7841  Yoo Seung-Ho เปิดตัวในปี 1999 ด้วยการโฆษณาสำหร...
# 7842  รองศาสตราจารย์ Mom City Sukhumphan Boriphat เก...
#
#                                   th_llm_paraphrase_aug  \
# 0     Phatthira Saruritphong Phokin ซึ่งเกิดเมื่อวัน...
# 1     Cleopatra VII Philopator หรือที่รู้จักกันในชื่...
# 2     ออสเตรเลียซึ่งเป็นที่รู้จักอย่างเป็นทางการในฐา...
# 3     วันสันติภาพไทยมีการเฉลิมฉลองเป็นประจำทุกปีในวั...
# 4     นิวซีแลนด์หรือที่รู้จักกันในชื่อ Aotearoa หรือ...
# ...                                                 ...
# 7838  สีดำเป็นสีที่เกี่ยวข้องกับพระอิศวรซึ่งเป็นการแ...
# 7839  Jan Van Eyck ศิลปินชาวดัตช์ที่เกิดประมาณปี 139...
# 7840  BioShock Infinite เป็นวิดีโอเกมยิงคนแรกจากเกมท...
# 7841  Yoo Seung-ho เปิดตัวในปี 1999 ด้วยโฆษณาสำหรับ ...
# 7842  ดร. รองศาสตราจารย์ Mom City Sukhumphan Boripha...
#
#                                         th_qcpg_0.2_aug  \
# 0     Phatthira Saruuritt Phokin (เกิดเมื่อวันที่ 3 ...
# 1     - 69 - 69 - โต๊ะ (Laug พ่อของเธอ A Wolf Mi, 12...
# 2     กลุ่มออสเตรเลีย (ออสเตรเลีย), Tae-Samanthin แล...
# 3     วันสันติภาพไทยเป็นวันที่ 16 ของ AUGUST 1945 แล...
# 4     นิวซีแลนด์ (Aotearoa) เป็นดินแดนที่มีเมฆสีขาวอ...
# ...                                                 ...
# 7838  สีดำเป็นสีของพระอิศวรคนที่ดื่มเพื่อปกป้องมนุษย...
# 7839  Jan Van Eyck จาก 1395 - ก่อนวันที่ 9 กรกฎาคม ค...
# 7840  Biohock Infinite เป็นวิดีโอที่สร้างขึ้นโดยชายค...
# 7841  Joo Seung-Ho เปิดตัวซึ่งเป็นนักแสดงเด็กตอนอายุ...
# 7842  ผู้ก่อตั้งการประชุมกรุงเทพฯ Mr. Muhman Bukhumf...
#
#                                 th_qcpg_0.2_llm_gec_aug  \
# 0     Phatthira Saruutfokin (เกิดเมื่อวันที่ 3 ธันวา...
# 1     Cleopatra VII หรือที่รู้จักกันในชื่อ Cleopatra...
# 2     ออสเตรเลียซึ่งเรียกว่าออสเตรเลียอย่างเป็นทางกา...
# 3     วันแห่งความสงบสุขของไทยมีการเฉลิมฉลองในวันที่ ...
# 4     นิวซีแลนด์ (Aotearoa, นิวซีแลนด์, ดินแดนแห่งเม...
# ...                                                 ...
# 7838  สีดำคืออะไรเมื่อเผชิญกับเรื่องราวของ SIV เกี่ย...
# 7839  Jan Van Eyck (จาก 1395 ถึง 1441) เป็นศิลปินชาว...
# 7840  Biohock Infinite เป็นวิดีโอเกมคนแรกซึ่งออกอากา...
# 7841  Joo Seung-Ho เป็นคนแรกที่ได้รับการติดต่อในปี 1...
# 7842  ผู้ก่อตั้ง SGAPA (ประธานคณะกรรมาธิการ) เมื่อวั...
#
#                                         th_qcpg_0.5_aug  \
# 0     ชื่อของ Phatthira Saruuritt Phokin (เกิดในโรงเ...
# 1     ดังนั้นครอบครัวกรีกคนสุดท้ายของราชวงศ์สตากา-เม...
# 2     กลุ่มออสเตรเลีย (ออสเตรเลีย), Tae-Samanthin แล...
# 3     วันสันติภาพไทยเป็นวันที่ 16 ของ AUGUST 1945 แล...
# 4     นิวซีแลนด์ (Aotearoa: Aotearoa ประเทศฟินแลนด์ป...
# ...                                                 ...
# 7838  สีดำเป็นสีของพระอิศวรคนที่ดื่มเพื่อปกป้องมนุษย...
# 7839  Jan Van Eyck จาก 1395 - ก่อนวันที่ 9 กรกฎาคม ค...
# 7840  Biohock Infinite เป็นวิดีโอซึ่งสร้างขึ้นโดยชาย...
# 7841  Joo Seung-Ho เปิดตัวซึ่งเป็นนักแสดงเด็กตอนอายุ...
# 7842             (2) การลงทะเบียนของสหภาพยุโรปศ. M. M.?
#
#                                 th_qcpg_0.5_llm_gec_aug  ... dis_fasttext_aug  \
# 0     Phatthira Saruutfokin (เกิดเมื่อวันที่ 3 ธันวา...  ...         0.222455
# 1     Cleopatra VII หรือที่รู้จักกันในชื่อคลีโอพัตรา...  ...         0.193210
# 2     กลุ่มออสเตรเลียหรือที่รู้จักกันในชื่อกลุ่มออสเ...  ...         0.190002
# 3     วันแห่งความสงบสุขของไทยมีการเฉลิมฉลองในวันที่ ...  ...         0.152328
# 4     นิวซีแลนด์ (Aotearoa, นิวซีแลนด์และสาธารณรัฐอั...  ...         0.123369
# ...                                                 ...  ...              ...
# 7838  สัญลักษณ์สีดำในเรื่องพระอิศวรเกี่ยวกับการปกป้อ...  ...         0.000000
# 7839  Jan Van Eyck (จาก 1395 ถึง 1441) เป็นศิลปินชาว...  ...         0.000000
# 7840  Biohock Infinite เป็นการยิงครั้งแรกของชายคนหนึ...  ...         0.007139
# 7841  ในปี 1999 Joo Seung-Ho เป็นคนแรกที่เปรียบเทียบ...  ...         0.000000
# 7842  เมื่อวันที่ 22 กันยายน 2495 ศาสตราจารย์ที่เกี่...  ...         0.000000
#
#      dis_llm_gec_aug dis_llm_paraphrase_aug dis_qcpg_0.2_aug  \
# 0           0.388602               0.473647         0.668879
# 1           0.516863               0.527163         0.552196
# 2           0.447664               0.367073         0.502999
# 3           0.281156               0.355830         0.620467
# 4           0.346898               0.371927         0.401425
# ...              ...                    ...              ...
# 7838        0.851206               0.910764         0.938280
# 7839        0.257012               0.432358         0.262410
# 7840        0.285130               0.259821         0.583060
# 7841        0.384488               0.329706         0.494374
# 7842        0.648618               0.650185         0.876633
#
#      dis_qcpg_0.2_llm_gec_aug dis_qcpg_0.5_aug dis_qcpg_0.5_llm_gec_aug  \
# 0                    0.648198         0.667289                 0.574154
# 1                    0.648432         0.498711                 0.589142
# 2                    0.547885         0.498996                 0.509347
# 3                    0.543739         0.535929                 0.503892
# 4                    0.580319         0.554076                 0.490527
# ...                       ...              ...                      ...
# 7838                 0.749168         0.938280                 0.834230
# 7839                 0.458792         0.278083                 0.458792
# 7840                 0.596329         0.537655                 0.591335
# 7841                 0.506072         0.499449                 0.527325
# 7842                 0.536940         0.990290                 0.665018
#
#      dis_qcpg_0.8_aug dis_qcpg_0.8_llm_gec_aug dis_wordnet_aug
# 0            0.685752                 0.600663        0.082608
# 1            0.591064                 0.570499        0.067832
# 2            0.520477                 0.423167        0.091202
# 3            0.530591                 0.517936        0.081795
# 4            0.463700                 0.525312        0.066453
# ...               ...                      ...             ...
# 7838         0.878455                 1.002430        0.290303
# 7839         0.409889                 0.449810        0.097465
# 7840         0.358857                 0.401114        0.027237
# 7841         0.496102                 0.601321        0.116840
# 7842         1.044921                 0.912211        0.303261
#
# [7843 rows x 33 columns]

# %%
# Get all numerical columns in data
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
numerical_columns
# Out:
# Index(['dis_aug', 'dis_fasttext_aug', 'dis_llm_gec_aug',
#        'dis_llm_paraphrase_aug', 'dis_qcpg_0.2_aug',
#        'dis_qcpg_0.2_llm_gec_aug', 'dis_qcpg_0.5_aug',
#        'dis_qcpg_0.5_llm_gec_aug', 'dis_qcpg_0.8_aug',
#        'dis_qcpg_0.8_llm_gec_aug', 'dis_wordnet_aug'],
#       dtype='object')

# %% [markdown]
# # Distance Statistics

# %%
# Plotting
sns.set(style="whitegrid")
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 14))

# First plot with Boxplot for distribution
sns.boxplot(data=data[numerical_columns], orient='h', palette="Set2", ax=axs[0])
axs[0].set_title('Box Plot (Distribution statistics)')

# Second plot with KDE plots for each data set
data[numerical_columns].plot(kind='density', ax=axs[1])
axs[1].set_title('Kernel Density Estimation (KDE) Plot')

plt.tight_layout()
plt.show()

# %%
num_datasets = len(numerical_columns)

# Calculate the number of rows and columns to create a grid
num_rows = int(np.ceil(num_datasets / 3.))  # Change divisor to control number of columns
num_cols = 3  # Change this to control number of columns

fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, num_rows * 4))

for ind, column in enumerate(numerical_columns):
    i = ind // num_cols
    j = ind % num_cols
    sns.histplot(data[column], kde=True, ax=axs[i, j])
    axs[i, j].set_title(column)

# Remove empty subplots
if num_datasets % num_cols != 0:
    for idx in range(num_datasets, num_rows*num_cols):
        fig.delaxes(axs.flatten()[idx])

plt.tight_layout()
plt.show()

# %% [markdown]
# # ReQA Analysis

# %%
reqa_results = pd.read_csv("results/07_benchmark_reqa.csv")
reqa_results
# Out:
#     source                     name  top_1  top_5  top_10  norm_top_1
# 0     iapp                 original     42    172     223    0.005812  \
# 1     iapp                   th_aug    197    356     395    0.027263
# 2     iapp          th_fasttext_aug    522    958    1081    0.072239
# 3     iapp           th_llm_gec_aug    166    306     351    0.022973
# 4     iapp    th_llm_paraphrase_aug    155    293     335    0.021450
# 5     iapp             th_ltw2v_aug   1288   2138    2292    0.178245
# 6     iapp          th_qcpg_0.2_aug     77    156     194    0.010656
# 7     iapp  th_qcpg_0.2_llm_gec_aug     61    149     184    0.008442
# 8     iapp          th_qcpg_0.5_aug     86    172     213    0.011901
# 9     iapp  th_qcpg_0.5_llm_gec_aug     71    162     202    0.009826
# 10    iapp          th_qcpg_0.8_aug    101    216     266    0.013977
# 11    iapp  th_qcpg_0.8_llm_gec_aug     94    204     242    0.013009
# 12    iapp          th_thai2fit_aug   1384   2023    2193    0.191531
# 13    iapp           th_wordnet_aug   2134   2916    3044    0.295322
# 14  thaiqa                 original     32     99     138    0.007899
# 15  thaiqa                   th_aug    156    245     285    0.038509
# 16  thaiqa          th_fasttext_aug    393    617     718    0.097013
# 17  thaiqa           th_llm_gec_aug    138    214     238    0.034066
# 18  thaiqa    th_llm_paraphrase_aug    135    210     242    0.033325
# 19  thaiqa             th_ltw2v_aug   1277   1623    1748    0.315231
# 20  thaiqa          th_qcpg_0.2_aug     55    108     128    0.013577
# 21  thaiqa  th_qcpg_0.2_llm_gec_aug     46     87     106    0.011355
# 22  thaiqa          th_qcpg_0.5_aug     61    108     131    0.015058
# 23  thaiqa  th_qcpg_0.5_llm_gec_aug     57     96     131    0.014071
# 24  thaiqa          th_qcpg_0.8_aug     88    167     197    0.021723
# 25  thaiqa  th_qcpg_0.8_llm_gec_aug     78    132     170    0.019255
# 26  thaiqa          th_thai2fit_aug   1465   1767    1852    0.361639
# 27  thaiqa           th_wordnet_aug   1803   2045    2099    0.445075
# 28   xquad                 original     19     67      95    0.016102
# 29   xquad                   th_aug    117    158     176    0.099153
# 30   xquad          th_fasttext_aug    105    160     181    0.088983
# 31   xquad           th_llm_gec_aug    113    153     172    0.095763
# 32   xquad    th_llm_paraphrase_aug     97    147     163    0.082203
# 33   xquad             th_ltw2v_aug    193    275     304    0.163559
# 34   xquad          th_qcpg_0.2_aug     42     77      95    0.035593
# 35   xquad  th_qcpg_0.2_llm_gec_aug     39     75      85    0.033051
# 36   xquad          th_qcpg_0.5_aug     40     74      96    0.033898
# 37   xquad  th_qcpg_0.5_llm_gec_aug     48     80      91    0.040678
# 38   xquad          th_qcpg_0.8_aug     75    106     121    0.063559
# 39   xquad  th_qcpg_0.8_llm_gec_aug     67    100     113    0.056780
# 40   xquad          th_thai2fit_aug    206    292     317    0.174576
# 41   xquad           th_wordnet_aug    303    340     350    0.256780
# 42  tydiqa                 original     28     57      70    0.006191
# 43  tydiqa                   th_aug     90    161     195    0.019898
# 44  tydiqa          th_fasttext_aug    409    721     825    0.090427
# 45  tydiqa           th_llm_gec_aug     84    148     178    0.018572
# 55    0.407694     0.424055   0.363046         4523

# %%
reqa_results.sort_values('norm_top_1', ascending=False)
# Out:
#     source                     name  top_1  top_5  top_10  norm_top_1
# 27  thaiqa           th_wordnet_aug   1803   2045    2099    0.445075  \
# 26  thaiqa          th_thai2fit_aug   1465   1767    1852    0.361639
# 55  tydiqa           th_wordnet_aug   1495   1844    1918    0.330533
# 19  thaiqa             th_ltw2v_aug   1277   1623    1748    0.315231
# 13    iapp           th_wordnet_aug   2134   2916    3044    0.295322
# 54  tydiqa          th_thai2fit_aug   1230   1744    1854    0.271943
# 41   xquad           th_wordnet_aug    303    340     350    0.256780
# 47  tydiqa             th_ltw2v_aug    953   1408    1529    0.210701
# 12    iapp          th_thai2fit_aug   1384   2023    2193    0.191531
# 5     iapp             th_ltw2v_aug   1288   2138    2292    0.178245
# 40   xquad          th_thai2fit_aug    206    292     317    0.174576
# 33   xquad             th_ltw2v_aug    193    275     304    0.163559
# 29   xquad                   th_aug    117    158     176    0.099153
# 16  thaiqa          th_fasttext_aug    393    617     718    0.097013
# 31   xquad           th_llm_gec_aug    113    153     172    0.095763
# 44  tydiqa          th_fasttext_aug    409    721     825    0.090427
# 30   xquad          th_fasttext_aug    105    160     181    0.088983
# 32   xquad    th_llm_paraphrase_aug     97    147     163    0.082203
# 2     iapp          th_fasttext_aug    522    958    1081    0.072239
# 38   xquad          th_qcpg_0.8_aug     75    106     121    0.063559
# 39   xquad  th_qcpg_0.8_llm_gec_aug     67    100     113    0.056780
# 37   xquad  th_qcpg_0.5_llm_gec_aug     48     80      91    0.040678
# 15  thaiqa                   th_aug    156    245     285    0.038509
# 34   xquad          th_qcpg_0.2_aug     42     77      95    0.035593
# 17  thaiqa           th_llm_gec_aug    138    214     238    0.034066
# 36   xquad          th_qcpg_0.5_aug     40     74      96    0.033898
# 18  thaiqa    th_llm_paraphrase_aug    135    210     242    0.033325
# 35   xquad  th_qcpg_0.2_llm_gec_aug     39     75      85    0.033051
# 1     iapp                   th_aug    197    356     395    0.027263
# 3     iapp           th_llm_gec_aug    166    306     351    0.022973
# 24  thaiqa          th_qcpg_0.8_aug     88    167     197    0.021723
# 4     iapp    th_llm_paraphrase_aug    155    293     335    0.021450
# 43  tydiqa                   th_aug     90    161     195    0.019898
# 25  thaiqa  th_qcpg_0.8_llm_gec_aug     78    132     170    0.019255
# 45  tydiqa           th_llm_gec_aug     84    148     178    0.018572
# 46  tydiqa    th_llm_paraphrase_aug     74    141     172    0.016361
# 28   xquad                 original     19     67      95    0.016102
# 22  thaiqa          th_qcpg_0.5_aug     61    108     131    0.015058
# 23  thaiqa  th_qcpg_0.5_llm_gec_aug     57     96     131    0.014071
# 10    iapp          th_qcpg_0.8_aug    101    216     266    0.013977
# 20  thaiqa          th_qcpg_0.2_aug     55    108     128    0.013577
# 53  tydiqa  th_qcpg_0.8_llm_gec_aug     61    118     132    0.013487
# 11    iapp  th_qcpg_0.8_llm_gec_aug     94    204     242    0.013009
# 52  tydiqa          th_qcpg_0.8_aug     58    123     150    0.012823
# 8     iapp          th_qcpg_0.5_aug     86    172     213    0.011901
# 21  thaiqa  th_qcpg_0.2_llm_gec_aug     46     87     106    0.011355
